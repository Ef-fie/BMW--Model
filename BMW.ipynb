# %%
import pandas as pd
import numpy as np
df= pd.read_csv("C:\\Users\\effie\\Downloads\\archive (5)\\bmw.csv")
df.head(10)
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# 5   5 Series  2016  14900    Automatic    35309   Diesel  125  60.1
# 6   5 Series  2017  16000    Automatic    38538   Diesel  125  60.1
# 7   2 Series  2018  16250       Manual    10401   Petrol  145  52.3
# 8   4 Series  2017  14250       Manual    42668   Diesel   30  62.8
# 9   5 Series  2016  14250    Automatic    36099   Diesel   20  68.9
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0
# 5         2.0
# 6         2.0
# 7         1.5
# 8         2.0
# 9         2.0

# %%
#getting the number of rows and columns
df.shape
# Out:
# (10781, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB

# %%
#Checking for null values
#Recheck after cleaning
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10781.000000   10781.000000   10781.000000  10781.000000  10781.000000
# mean    2017.078935   22733.408867   25496.986550    131.702068     56.399035
# std        2.349038   11415.528189   25143.192559     61.510755     31.336958
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14950.000000    5529.000000    135.000000     45.600000
# 50%     2017.000000   20462.000000   18347.000000    145.000000     53.300000
# 75%     2019.000000   27940.000000   38206.000000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10781.000000
# mean       2.167767
# std        0.552054
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
#Selecting prediction target using dot method
y= df. price
#Selecting features using column method
df_features = ['year', 'mileage', 'tax', 'mpg', 'engineSize']
x = df[df_features]

# %%
x.describe()
# Out:
#                year        mileage           tax           mpg    engineSize
# count  10781.000000   10781.000000  10781.000000  10781.000000  10781.000000
# mean    2017.078935   25496.986550    131.702068     56.399035      2.167767
# std        2.349038   25143.192559     61.510755     31.336958      0.552054
# min     1996.000000       1.000000      0.000000      5.500000      0.000000
# 25%     2016.000000    5529.000000    135.000000     45.600000      2.000000
# 50%     2017.000000   18347.000000    145.000000     53.300000      2.000000
# 75%     2019.000000   38206.000000    145.000000     62.800000      2.000000
# max     2020.000000  214000.000000    580.000000    470.800000      6.600000

# %%
x.head()
# Out:
#    year  mileage  tax   mpg  engineSize
# 0  2014    67068  125  57.6         2.0
# 1  2018    14827  145  42.8         2.0
# 2  2016    62794  160  51.4         3.0
# 3  2017    26676  145  72.4         1.5
# 4  2014    39554  160  50.4         3.0

# %%
from sklearn.tree import DecisionTreeRegressor
# Define model. Specify a number for random_state to ensure same results each run
BMW_model = DecisionTreeRegressor(random_state=1)
# Fit model
BMW_model.fit(x, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
from sklearn.model_selection import train_test_split

# split data into training and validation data, for both features and target
# The split is based on a random number generator. Supplying a numeric value to
# the random_state argument guarantees we get the same split every time we
# run this script.
train_x, val_x, train_y, val_y = train_test_split(x, y, random_state = 0)
# Define model
BMW_model = DecisionTreeRegressor()
# Fit model
BMW_model.fit(train_x, train_y)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

def get_mae(max_leaf_nodes, train_x, val_x, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_x, train_y)
    preds_val = model.predict(val_x)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)
# get predicted prices on validation data
val_predictions = BMW_model.predict(val_x)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 2801.300113122535

# %%
# compare MAE with differing values of max_leaf_nodes
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_x, val_x, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  4588
# Max leaf nodes: 50  		 Mean Absolute Error:  3068
# Max leaf nodes: 500  		 Mean Absolute Error:  2542
# Max leaf nodes: 5000  		 Mean Absolute Error:  2806

# %%
#dropping a column
df= df.drop(columns=['tax'])

# %%
'tax' in df.columns
# Out:
# False

# %%
#Selecting prediction target using dot method
new_y= df. price
#Selecting features using column method
df_features = ['year', 'mileage', 'mpg', 'engineSize']
new_x = df[df_features]

# %%
from sklearn.tree import DecisionTreeRegressor
# Define model. Specify a number for random_state to ensure same results each run
BMW_model2 = DecisionTreeRegressor(random_state=1)
# Fit model
BMW_model2.fit(new_x, new_y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
from sklearn.model_selection import train_test_split

# split data into training and validation data, for both features and target
# The split is based on a random number generator. Supplying a numeric value to
# the random_state argument guarantees we get the same split every time we
# run this script.
train_new_x, val_new_x, train_new_y, val_new_y = train_test_split(new_x, new_y, random_state = 0)
# Define model
BMW_model2 = DecisionTreeRegressor()
# Fit model
BMW_model2.fit(train_new_x, train_new_y)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

def get_mae(max_leaf_nodes, train_new_x, val_new_x, train_new_y, val_new_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_new_x, train_new_y)
    preds_val = model.predict(val_new_X)
    mae = mean_absolute_error(val_new_y, preds_val)
    return(mae)
# get predicted prices on validation data
val_predictions = BMW_model2.predict(val_new_x)
print(mean_absolute_error(val_new_y, val_predictions))
# Out:
# 2741.710544802626

# %%
# compare MAE with differing values of max_leaf_nodes
for max_leaf_nodes in [5, 50, 500, 5000]:
    my_mae = get_mae(max_leaf_nodes, train_new_x, val_new_x, train_new_y, val_new_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# Max leaf nodes: 5  		 Mean Absolute Error:  4588
# Max leaf nodes: 50  		 Mean Absolute Error:  3081
# Max leaf nodes: 500  		 Mean Absolute Error:  2461
# Max leaf nodes: 5000  		 Mean Absolute Error:  2734

# %%
from sklearn.tree import DecisionTreeRegressor

BMW_model2  = DecisionTreeRegressor(max_leaf_nodes=500, random_state=1)
BMW_model2 .fit(train_new_x, train_new_y)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=500, random_state=1)

# %%
import joblib

# save model
joblib.dump(model, 'BMW_model2.pkl')
# Out:
# ['BMW_model2.pkl']

# %%
# load model later
#import joblib
#loaded_model = joblib.load('bmw_price_model.pkl')
#predictions = loaded_model.predict(new_data)
#print(predictions)
